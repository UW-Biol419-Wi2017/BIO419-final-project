# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
df=pd.read_excel('Data.xlsx')

# %%
df

# %%
df_Male=df.loc[df['Victim Sex']=='Male']
df_male=df_Male.groupby(['State']).count()
df_male1=df_male.drop('Year',1)

df_Fem=df.loc[df['Victim Sex']=='Female']
df_female=df_Fem.groupby(['State']).count()
df_female1=df_female.drop('Year',1)
df_F_M1 =[df_male1,df_female1] 
df_F_M=pd.concat(df_F_M1,axis=1)
df_F_M.plot(kind='bar',color=['blue','pink'],stacked=True)
plt.legend(['Male','Female'])

plt.title('Victim Sex and incidence ')

# %%
df_Fem['State'].value_counts().plot.pie(fontsize=7,autopct='%.2f')
plt.title('Female victim')

# %%
df_Male['State'].value_counts().plot.pie(autopct='%.2f')
plt.title('Male Victim')

# %%
df2=pd.read_excel('Data2.xlsx')
df2

# %%
df_Jan=df2.loc[df2['Month']=='January']
df_Jan1=df_Jan.groupby(['State']).sum()

# %%
df_Feb=df2.loc[df2['Month']=='February']
df_Feb2=df_Feb.groupby(['State']).sum()

# %%
df_March=df2.loc[df2['Month']=='March']
df_Mar3=df_March.groupby(['State']).sum()

df_Apr=df2.loc[df2['Month']=='April']
df_Apr4=df_Apr.groupby(['State']).sum()

df_May=df2.loc[df2['Month']=='May']
df_May5=df_May.groupby(['State']).sum()

df_June=df2.loc[df2['Month']=='June']
df_June6=df_June.groupby(['State']).sum()

df_July=df2.loc[df2['Month']=='July']
df_July7=df_July.groupby(['State']).sum()

df_Aug=df2.loc[df2['Month']=='August']
df_Aug8=df_Aug.groupby(['State']).sum()

df_Sep=df2.loc[df2['Month']=='September']
df_Sep9=df_Sep.groupby(['State']).sum()

df_Oct=df2.loc[df2['Month']=='October']
df_Oct10=df_Oct.groupby(['State']).sum()

df_Nov=df2.loc[df2['Month']=='November']
df_Nov11=df_Nov.groupby(['State']).sum()

df_Dec=df2.loc[df2['Month']=='December']
df_Dec12=df_Dec.groupby(['State']).sum()

# %%
df_Month =[df_Jan1,df_Feb2,df_Mar3,df_Apr4,df_May5,df_June6,df_July7,df_Aug8,df_Sep9,df_Oct10,df_Nov11,df_Dec12]

# %%
df_AMonth=pd.concat(df_Month,axis=1)


df_AMonth.T.plot.box()
plt.title('Variation of incident rate in 12-month by states ')

# %%
import mca

# %%
dataframe=pd.read_csv('database.csv')
dataframe
DataO=dataframe.drop(['Record ID','Agency Code','Agency Name','Agency Type','Record Source'],axis =1 )
DataO
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                    City          State  Year      Month  Incident  \
# 0             Anchorage         Alaska  1980    January         1
# 1             Anchorage         Alaska  1980      March         1
# 2             Anchorage         Alaska  1980      March         2
# 3             Anchorage         Alaska  1980      April         1
# 4             Anchorage         Alaska  1980      April         2
# 5             Anchorage         Alaska  1980        May         1
# 6             Anchorage         Alaska  1980        May         2
# 7             Anchorage         Alaska  1980       June         1
# 8             Anchorage         Alaska  1980       June         2
# 9             Anchorage         Alaska  1980       June         3
# 10            Anchorage         Alaska  1980       July         1
# 11            Anchorage         Alaska  1980       July         2
# 20                            Unknown          Unknown            Male
# 21                            Unknown          Unknown            Male
# 22                            Unknown          Unknown            Male
# 23                            Unknown          Unknown            Male
# 24                            Unknown          Unknown            Male
# 25                              White          Unknown            Male
# 26                              Black          Unknown         Unknown
# 27      Native American/Alaska Native          Unknown          Female
# 28      Native American/Alaska Native          Unknown          Female
# 29                            Unknown          Unknown            Male
# ...                               ...              ...             ...
# 638424                          White          Unknown          Female
# 638425                          White          Unknown            Male
# 638426                          White          Unknown            Male
# 638427                          White          Unknown            Male
# 638428                          White          Unknown            Male
# 638429                          White          Unknown            Male
# 638430                          White          Unknown            Male
# 638431                          White          Unknown            Male
# 638432                          White          Unknown            Male
# 638433                          White          Unknown          Female
# 638434                          White          Unknown          Female
# 638435                          White          Unknown          Female
# 638436                          White          Unknown         Unknown
# 638437                          White          Unknown         Unknown
# 638438                          White          Unknown         Unknown
# 638439                          White          Unknown            Male
# 638440                          White          Unknown            Male
# 638441                          White     Not Hispanic            Male
# 638442                          White     Not Hispanic            Male
# 638443                          White          Unknown            Male
# 638444                          White         Hispanic            Male
# 638445                          White          Unknown            Male
# 638446                          White     Not Hispanic            Male
# 638447                          Black     Not Hispanic            Male
# 638448  Native American/Alaska Native          Unknown            Male
# 638449                          White         Hispanic         Unknown
# 638450                          White          Unknown            Male
# 638451         Asian/Pacific Islander          Unknown          Female
# 638452                          White     Not Hispanic            Male
# 638453                          White     Not Hispanic          Female
#
#        Perpetrator Age               Perpetrator Race Perpetrator Ethnicity  \
# 0                   15  Native American/Alaska Native               Unknown
# 1                   42                          White               Unknown
# 2                    0                        Unknown               Unknown
# 3                   42                          White               Unknown
# 4                    0                        Unknown               Unknown
# 5                   36                          White               Unknown
# 6                   27                          Black               Unknown
# 7                   35                          White               Unknown
# 8                    0                        Unknown               Unknown
# 9                   40                        Unknown               Unknown
# 10                   0                        Unknown               Unknown
# 11                  49                          White               Unknown
# 12                  39                          Black               Unknown
# 13                  49                          White               Unknown
# 14                   0                        Unknown               Unknown
# 15                  29                          Black               Unknown
# 16                  19                        Unknown               Unknown
# 17                  23  Native American/Alaska Native               Unknown
# 18                  33  Native American/Alaska Native               Unknown
# 19                  35  Native American/Alaska Native               Unknown
# 20                  29                        Unknown               Unknown
# 21                  29                        Unknown               Unknown
# 22                  26                        Unknown               Unknown
# 23                  41                        Unknown               Unknown
# 24                  29                        Unknown               Unknown
# 25                  42                          White               Unknown
# 26                   0                        Unknown               Unknown
# 27                  28  Native American/Alaska Native               Unknown
# 28                  36  Native American/Alaska Native               Unknown
# 29                  61  Native American/Alaska Native               Unknown
# ...                ...                            ...                   ...
# 638424              23                          White               Unknown
# 638425              45                          White               Unknown
# 638426              39                          White               Unknown
# 638427              39                          White               Unknown
# 638428              23                          White               Unknown
# 638429              18                          White               Unknown
# 638430              29                          White               Unknown
# 638431              22                          White               Unknown
# 638432              24                          White               Unknown
# 638433              30                          White               Unknown
# 638434              35                          White               Unknown
# 638435              35                          White               Unknown
# 638451      Daughter    Suffocation             0                  0
# 638452      Stranger          Knife             0                  1
# 638453      Daughter   Blunt Object             0                  1
#
# [638454 rows x 19 columns]

# %%
def list_par(x,l):
    if x not in l :
        l[x]=len(l)
    return l

# %%
dic_city = {}
for city in DataO['City']:
    (list_par(city,dic_city))

dic_state = {}
for state in DataO['State']:
    (list_par(state,dic_state))
    
dic_crime_type = {}
for crime_type in DataO['Crime Type']:
    (list_par(crime_type,dic_crime_type))

dic_crime_solved={}
for crime_solved in DataO['Crime Solved']:
    (list_par(crime_solved,dic_crime_solved))



dic_victim_race = {}
for victim_race in DataO['Victim Race']:
    (list_par(victim_race,dic_victim_race))
    
dic_victim_ethnicity = {}
for victim_ethnicity in DataO['Victim Ethnicity']:
    (list_par(victim_ethnicity,dic_victim_ethnicity))
    
dic_perpetrator_race = {}
for perpetrator_race in DataO['Perpetrator Race']:
    (list_par(perpetrator_race,dic_perpetrator_race))
    
dic_perpetrator_sex = {}
for perpetrator_sex in DataO['Perpetrator Sex']:
    (list_par(perpetrator_sex,dic_perpetrator_sex))
    
dic_perpetrator_ethnicity = {}
for perpetrator_ethnicity in DataO['Perpetrator Ethnicity']:
    (list_par(perpetrator_ethnicity,dic_perpetrator_ethnicity))
    
dic_relationship = {}
for relationship in DataO['Relationship']:
    (list_par(relationship,dic_relationship))

dic_weapon = {}
for weapon in DataO['Weapon']:
    (list_par(weapon,dic_weapon))

dic_month = {}
for month in DataO['Month']:
    (list_par(month,dic_month))
    
dic_sexe = {}
for sexe in DataO['Victim Sex']:
    (list_par(sexe,dic_sexe))

# %%
DataO['Month']=DataO['Month'].map(dic_month)
DataO['Victim Sex']=DataO['Victim Sex'].map(dic_sexe)
DataO['City']=DataO['City'].map(dic_city)
DataO['State']=DataO['State'].map(dic_state)
DataO['Crime Type']=DataO['Crime Type'].map(dic_crime_type)
DataO['Crime Solved']=DataO['Crime Solved'].map(dic_crime_solved)
DataO['Victim Race']=DataO['Victim Race'].map(dic_victim_race)
DataO['Victim Ethnicity']=DataO['Victim Ethnicity'].map(dic_victim_ethnicity)
DataO['Perpetrator Race']=DataO['Perpetrator Race'].map(dic_perpetrator_race)
DataO['Perpetrator Sex']=DataO['Perpetrator Sex'].map(dic_perpetrator_sex)
DataO['Perpetrator Ethnicity']=DataO['Perpetrator Ethnicity'].map(dic_perpetrator_ethnicity)
DataO['Relationship']=DataO['Relationship'].map(dic_relationship)
DataO['Weapon']=DataO['Weapon'].map(dic_weapon)
DataO

# %%
import mca

# %%
DataO.shape
# Out:
# (638454, 19)

# %%
Data_mca=mca.mca(DataO)
print(Data_mca)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# //anaconda/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#     985             result = expressions.evaluate(op, str_rep, x, y,
# --> 986                                           raise_on_error=True, **eval_kwargs)
#     987         except TypeError:
#
# //anaconda/lib/python3.5/site-packages/pandas/computation/expressions.py in evaluate(op, op_str, a, b, raise_on_error, use_numexpr, **eval_kwargs)
#     208         return _evaluate(op, op_str, a, b, raise_on_error=raise_on_error,
# --> 209                          **eval_kwargs)
#     210     return _evaluate_standard(op, op_str, a, b, raise_on_error=raise_on_error)
#
# //anaconda/lib/python3.5/site-packages/pandas/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, raise_on_error, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b, raise_on_error)
#     121
#
# //anaconda/lib/python3.5/site-packages/pandas/computation/expressions.py in _evaluate_standard(op, op_str, a, b, raise_on_error, **eval_kwargs)
#      61         _store_test_result(False)
# ---> 62     return op(a, b)
#      63
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# //anaconda/lib/python3.5/site-packages/pandas/core/internals.py in eval(self, func, other, raise_on_error, try_cast, mgr)
#    1131         try:
# -> 1132             result = get_result(other)
#    1133
#
# //anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get_result(other)
#    1102             else:
# -> 1103                 result = func(values, other)
#    1104
#
# //anaconda/lib/python3.5/site-packages/pandas/core/ops.py in na_op(x, y)
#    1002                 if np.prod(xrav.shape):
# -> 1003                     result[mask] = op(xrav, y)
#    1004             else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-f085690e9114> in <module>()
# ----> 1 Data_mca=mca.mca(DataO)
#       2 print(Data_mca)
#
# /Users/mac/.local/lib/python3.5/site-packages/mca.py in __init__(self, DF, cols, ncols, benzecri, TOL)
#      40                         X = DF
#      41                 S = X.sum().sum()
# ---> 42                 Z = X/S # correspondence matrix
#      43                 self.r = Z.sum(axis=1)
#      44                 self.c = Z.sum()
#
# //anaconda/lib/python3.5/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1095                 self = self.fillna(fill_value)
#    1096
# -> 1097             return self._combine_const(other, na_op)
#    1098
#    1099     f.__name__ = name
#
# //anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _combine_const(self, other, func, raise_on_error)
#    3553
#    3554         new_data = self._data.eval(func=func, other=other,
# -> 3555                                    raise_on_error=raise_on_error)
#    3556         return self._constructor(new_data)
#    3557
#
# //anaconda/lib/python3.5/site-packages/pandas/core/internals.py in eval(self, **kwargs)
#    2909
#    2910     def eval(self, **kwargs):
# -> 2911         return self.apply('eval', **kwargs)
#    2912
#    2913     def quantile(self, **kwargs):
#
# //anaconda/lib/python3.5/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, raw, **kwargs)
#    2888
#    2889             kwargs['mgr'] = self
# -> 2890             applied = getattr(b, f)(**kwargs)
#    2891             result_blocks = _extend_blocks(applied, result_blocks)
#    2892
#
# //anaconda/lib/python3.5/site-packages/pandas/core/internals.py in eval(self, func, other, raise_on_error, try_cast, mgr)
#    1137             raise
#    1138         except Exception as detail:
# -> 1139             result = handle_error()
#    1140
#    1141         # technically a broadcast error in numpy can 'work' by returning a
#
# //anaconda/lib/python3.5/site-packages/pandas/core/internals.py in handle_error()
#    1121             if raise_on_error:
#    1122                 raise TypeError('Could not operate %s with block values %s' %
# -> 1123                                 (repr(other), str(detail)))
#    1124             else:
#    1125                 # return the values
#
# TypeError: Could not operate 1610065270 with block values unsupported operand type(s) for /: 'str' and 'int'
